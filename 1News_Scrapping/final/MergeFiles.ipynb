# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os

path = os.getcwd()

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv')

# %%
import pandas as pd
dfs = list()
for i, f in enumerate(files):
    data = pd.read_csv(f)
    dfs.append(data)

df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#       Unnamed: 0        Date  \
# 0              0  30-01-2020
# 1              1  30-01-2020
# 2              2  29-01-2020
# 3              3  29-01-2020
# 4              4  29-01-2020
# ...          ...         ...
# 7675         622  04-09-2023
# 7676         623  02-09-2023
# 7677         624  02-09-2023
# 7678         625  01-09-2023
# 7679         626  01-09-2023
#
#                                                    news
# 0         Posers on wish to get Tata Dam water for dist
# 1            Citizens gear up to wage another green war
# 2     Tata Motors raises bar for rivals with killer ...
# 3     Tata Motors raises bar for rivals with killer ...
# 4                  Sensex tanks 188 pts over Wuhan woes
# ...                                                 ...
# 7675  DCM Fadnavis lays foundation stone for war mus...
# 7676  August inflation to be high, will start easing...
# 7677  Inflation will start easing in Sep, says RBI G...
# 7678  Breathe! Delhi logs 2nd cleanest January-Augus...
# 7679                    Bondada Engg gets listed on BSE
#
# [7680 rows x 3 columns]

# %%
df.to_csv('final_news.csv')
